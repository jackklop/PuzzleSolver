# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
arr = np.array([340,363,358,362,299,291,291,264,291,291,291,293,276,284,209,214,208,124,125,236,125,125,125,250,125,126,221,133,222,150,124,124,125,126,124,123,126,130,124,124,125,124,124,125,125,277,124,131,125,125])

# %%
arr = arr / 1000

# %%
ser = pd.Series(arr)

# %%
plt.plot(ser)

# %%
ser.describe()
# Out:
# count    50.000000
# mean      0.193340
# std       0.082783
# min       0.123000
# 25%       0.125000
# 50%       0.130500
# 75%       0.276750
# max       0.363000
# dtype: float64

# %%
ser = pd.Series(np.array([299,319,221,223,222,222,222,334,222,222,236,222,221,222,236,222,222,221,236,276,229,173,271,77,69,76,70,68,70,71,67,68,70,69,69,69,69,69,69,69,69,68,69,69,69,69,69,70,69,69])/1000)

# %%
plt.grid()
plt.plot(ser)

# %%
ser.describe()
# Out:
# count    50.000000
# mean      0.147440
# std       0.088705
# min       0.067000
# 25%       0.069000
# 50%       0.073500
# 75%       0.222000
# max       0.334000
# dtype: float64

# %%
ser = pd.Series(np.array([144,168,166,166,165,173,166,507,166,165,168,167,168,165,166,207,167,166,168,166,166,166,174,166,167,167,172,208,167,166,168,166,166,70,76,348,69,69,69,69,69,69,69,69,69,70,68,71,69,69])/1000)

# %%
plt.grid()
plt.plot(ser)

# %%
ser.describe()
# Out:
# count    50.000000
# mean      0.147500
# std       0.076273
# min       0.068000
# 25%       0.070000
# 50%       0.166000
# 75%       0.167000
# max       0.507000
# dtype: float64

# %%
967,1014,986,986,986,986,987,985,973,1027,979,1020,965,319,319,319,318,319,319,319,319,319,319,319,319,320,319,317,333,320,318,320,319,318,973,319,320,319,319,320,278,319,319,320,319,319,320,318,320,944

# %%
ser = pd.Series(np.array([438,458,458,458,458,458,458,458,458,459,455,458,458,458,458,459,444,458,457,459,458,458,458,486,458,458,458,444,249,250,250,250,249,249,249,250,248,250,222,249,249,458,250,251,250,251,247,250,402,250])/1000)

# %%
plt.grid()
plt.plot(ser)

# %%
ser.describe()
# Out:
# count    50.000000
# mean      0.372520
# std       0.103101
# min       0.222000
# 25%       0.250000
# 50%       0.456000
# 75%       0.458000
# max       0.486000
# dtype: float64

# %%
def display_graph(nums):
    ser = pd.Series(np.array(nums))
    plt.grid()
    plt.plot(ser)
    plt.xlabel = "Index"
    plt.ylabel = "Time (ms)"
    plt.show()
    print(ser.describe())

# %%
display_graph([967,1014,986,986,986,986,987,985,973,1027,979,1020,965,319,319,319,318,319,319,319,319,319,319,319,319,320,319,317,333,320,318,320,319,318,973,319,320,319,319,320,278,319,319,320,319,319,320,318,320,944])
# Out:
# count    50.00000
# mean      0.51836
# std       0.30900
# min       0.27800
# 25%       0.31900
# 50%       0.31900
# 75%       0.96650
# max       1.02700
# dtype: float64

# %%
display_graph([968,987,972,1014,987,985,984,986,1000,987,930,973,985,972,972,987,1055,984,986,987,992,983,985,1000,958,986,986,986,986,972,985,1006,999,1000,971,1000,333,331,334,339,333,340,340,342,333,332,331,333,333,333])
# Out:
# count    50.000000
# mean      0.803660
# std       0.295797
# min       0.331000
# 25%       0.340500
# 50%       0.984000
# 75%       0.987000
# max       1.055000
# dtype: float64

# %%
display_graph([1472,1457,1181,1167,1193,1181,1185,1181,1181,1187,1180,1188,1181,1187,1195,1180,1576,1208,1181,1181,1208,1430,1208,1180,1181,1177,1152,903,902,902,901,902,1347,906,905,278,902,894,931,902,931,902,903,903,1027,861,901,902,906,1212])
# Out:
# count    50.00000
# mean      1.08402
# std       0.21432
# min       0.27800
# 25%       0.90300
# 50%       1.18000
# 75%       1.18700
# max       1.57600
# dtype: float64

# %%
display_graph([1288,1293,1277,1305,1346,1306,1305,1320,1305,1304,1320,1265,1306,1305,1332,1320,1305,1304,1307,1274,1306,1304,1307,1303,1306,1318,1305,1057,1041,1055,1054,1056,1055,1055,1056,1056,1054,1056,1041,1052,1056,1056,1055,1055,1056,1056,1055,1055,921,1064])
# Out:
# count    50.000000
# mean      1.187060
# std       0.131048
# min       0.921000
# 25%       1.055250
# 50%       1.275500
# 75%       1.305000
# max       1.346000
# dtype: float64

# %%
display_graph([18,12,8,8,7,7,7,7,8,7,7,7,7,8,6,7,7,7,7,8,7,7,7,6,8,7,8,6,7,7,7,7,7,7,7,8,7,7,7,7,6,8,7,7,7,7,7,7,7,7,8])
# Out:
# count    51.000000
# mean      7.431373
# std       1.734992
# min       6.000000
# 25%       7.000000
# 50%       7.000000
# 75%       7.000000
# max      18.000000
# dtype: float64

# %%
display_graph([19,12,10,9,8,10,8,9,9,8,9,10,8,8,8,8,8,8,9,9,7,8,8,8,7,8,10,8,9,7,8,10,8,7,8,8,9,8,10,10,7,7,7,8,10,9,7,9,7,9,8])
# Out:
# count    51.000000
# mean      8.647059
# std       1.831104
# min       7.000000
# 25%       8.000000
# 50%       8.000000
# 75%       9.000000
# max      19.000000
# dtype: float64

# %%
display_graph([25,23,23,23,23,31,22,24,23,24,21,22,22,22,22,22,22,24,22,22,21,23,23,22,21,20,21,20,21,20,22,21,21,21,21,21,21,22,20,21,21,21,20,22,20,23,20,21,20,20,21])
# Out:
# count    51.000000
# mean     21.843137
# std       1.793015
# min      20.000000
# 25%      21.000000
# 50%      22.000000
# 75%      22.500000
# max      31.000000
# dtype: float64

# %%
display_graph([26,26,23,23,23,22,23,22,21,21,21,24,20,22,22,24,23,21,24,22,23,21,20,21,21,22,20,22,21,21,21,22,21,21,21,20,21,20,21,20,22,20,21,21,21,21,21,20,20,21,21])
# Out:
# count    51.000000
# mean     21.607843
# std       1.415322
# min      20.000000
# 25%      21.000000
# 50%      21.000000
# 75%      22.000000
# max      26.000000
# dtype: float64

# %%
display_graph([78,55,71,54,51,69,54,52,53,56,51,51,53,53,52,54,52,52,53,56,51,51,56,51,51,51,52,50,51,51,50,51,51,50,52,56,53,56,51,53,50,64,53,53,50,50,50,52,50,51,59])
# Out:
# count    51.00000
# mean     53.72549
# std       5.51753
# min      50.00000
# 25%      51.00000
# 50%      52.00000
# 75%      54.00000
# max      78.00000
# dtype: float64

# %%
display_graph([54,52,54,52,51,62,53,56,59,53,52,54,56,52,53,52,51,52,56,50,50,50,50,56,50,50,50,50,50,51,50,49,50,51,50,53,51,51,52,51,50,53,52,51,50,50,50,50,52,52,52])
# Out:
# count    51.000000
# mean     51.980392
# std       2.509902
# min      49.000000
# 25%      50.000000
# 50%      51.000000
# 75%      53.000000
# max      62.000000
# dtype: float64

# %%
display_graph([131,114,131,106,110,111,108,108,107,106,109,108,110,108,111,109,105,122,105,106,106,106,105,112,113,106,106,106,106,106,106,108,106,107,105,106,106,107,105,105,106,106,106,107,106,104,106,116,105,105,106])
# Out:
# count     51.000000
# mean     108.450980
# std        5.629614
# min      104.000000
# 25%      106.000000
# 50%      106.000000
# 75%      108.500000
# max      131.000000
# dtype: float64

# %%
display_graph([114,108,106,110,108,111,110,107,107,108,107,110,108,112,115,113,106,106,107,105,112,105,105,106,106,113,109,114,105,114,106,105,106,106,105,106,106,105,106,106,106,107,106,105,107,115,120,106,105,105,111])
# Out:
# count     51.000000
# mean     108.176471
# std        3.514006
# min      105.000000
# 25%      106.000000
# 50%      107.000000
# 75%      110.000000
# max      120.000000
# dtype: float64
